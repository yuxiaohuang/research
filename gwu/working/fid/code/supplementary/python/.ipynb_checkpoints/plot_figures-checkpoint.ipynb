# %% [markdown]
# # Plot Figure 1

# %% [markdown]
# ## Load data

# %%
import pandas as pd

# Load the data
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)

# Specify the name of the columns
df.columns = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Class']

# Features
features = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width']

# Get the features
X = df[features].values

# Get the target
y = df['Class'].values

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# The label encoder for the target
le = LabelEncoder()

# Encode the target
y = le.fit_transform(y)

# %% [markdown]
# ## Create the figure folder

# %%
import os

# Make directory
directory = os.path.dirname('/Users/yhuang/Desktop/fid/result/figure/')
if not os.path.exists(directory):
    os.makedirs(directory)

# %% [markdown]
# ## The 2 $\times$ 4 matrix

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(22, 5))

# Entry (0, 0): the scatter plot between Petal width and Petal length

# Get the x values
x_col = features.index('Petal length')
x_vals = X[:, x_col]
x_vals_u = np.unique(x_vals)

# Get the y values
y_col = features.index('Petal width')
y_vals = X[:, y_col]
y_vals_u = np.unique(y_vals)

# Get the color, marker, and label
colors = ["red", "green", "blue"]
markers = ["o", "*", "s"]
labels = ["1", "2", "3"]

# Get the data
data = {}
for num in range(3):
    data_x = [x_vals[i] for i in range(len(y)) if y[i] == num]
    data_y = [y_vals[i] for i in range(len(y)) if y[i] == num]
    data[num] = [data_x, data_y]
    
ax = axs[0]

for num, color, marker, label in zip(data.keys(), colors, markers, labels):
    data_x, data_y = data[num]
    x_idxs = [list(x_vals_u).index(xi) for xi in data_x]
    y_idxs = [list(y_vals_u).index(yi) for yi in data_y]
    ax.scatter(x_idxs, y_idxs, c=color, marker=marker, s=500, label=label)

ax.legend(loc=(-0.18, 0.1), shadow=True, fontsize=40, frameon=False, handletextpad=-0.5)

# Get the length of x_vals and the mid index
n = len(x_vals_u)
mid = n // 2
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([x_vals_u[0], x_vals_u[mid], x_vals_u[n - 1]], fontsize=40)

n = len(y_vals_u)
mid = n // 2
ax.set_ylabel('Petal width', fontsize=40)
ax.set_yticks([0, mid, n - 1])
ax.set_yticklabels([y_vals_u[0], y_vals_u[mid], y_vals_u[n - 1]], fontsize=40)
ax.set_title('Column 1', fontsize=40)

# Entry (0, 1): the Probability distribution of Petal length for Setosa

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/blr/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-setosa') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[1]

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='red')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 2', fontsize=40)

# Entry (0, 2): the Probability distribution of Petal length for Versicolor

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/blr/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[2]

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='green')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

# ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 3', fontsize=40)

# Entry (0, 3): the Probability distribution of Petal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/blr/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-virginica') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[3]

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='blue')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

# ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 4', fontsize=40)

fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/iris_blr.pdf', dpi=300)
plt.show()

# %% [markdown]
# # The plot distribution function

# %%
def plot_distribution(row, col, file_name, class_name, feature_name, color, label, fontsize, title, xlabel, ylabel, xticks, xticklabels, decimal_place):    
    # Load the distribution file
    df = pd.read_csv(file_name, header=0)
    
    # Specify the name of the columns
    df.columns = ['yu', 'xj', 'xij', 'pij']
    
    df = df.loc[(df['yu'] == class_name) & (df['xj'] == feature_name)]

    # Get the feature values
    xijs = df['xij'].values

    # Get the probabilities
    pijs = df['pij'].values

    ax = axs[row][col]
    
    # Plot the bar chart
    ax.bar(range(len(xijs)), pijs, color=color, label=label)
    
    if label is not None:
        ax.legend(fontsize=fontsize)
        
    if title is not None:
        ax.set_title(title, fontsize=fontsize)
        
    if xlabel is not None:
        ax.set_xlabel(xlabel, fontsize=fontsize)
        
    if ylabel is not None:
        ax.set_ylabel(ylabel, fontsize=fontsize)

    n = len(xijs)
    if xticks is None:
        ax.set_xticks([0, n - 1])
    else:
        ax.set_xticks(xticks)

    if xticklabels is None:
        ax.set_xticklabels([round(xijs[0], decimal_place) if decimal_place is not None else int(xijs[0]),
                            round(xijs[n - 1], decimal_place) if decimal_place is not None else int(xijs[n - 1])], 
                           fontsize=fontsize)     
    else:
        ax.set_xticklabels(xticklabels, fontsize=fontsize)
        
    ax.set_ylim([0, 1])
    ax.set_yticks([0, 1])
    ax.set_yticklabels([0, 1], fontsize=fontsize)

# %% [markdown]
# # Plot Figure 2

# %%
fig, axs = plt.subplots(nrows=1, ncols=8, figsize=(44, 5))

# Entry (0, 0): the scatter plot between Petal width and Petal length

# Get the x values
x_col = features.index('Petal length')
x_vals = X[:, x_col]
x_vals_u = np.unique(x_vals)

# Get the y values
y_col = features.index('Petal width')
y_vals = X[:, y_col]
y_vals_u = np.unique(y_vals)

# Get the color, marker, and label
colors = ["red", "green", "blue"]
markers = ["o", "*", "s"]
labels = ["1", "2", "3"]

# Get the data
data = {}
for num in range(3):
    data_x = [x_vals[i] for i in range(len(y)) if y[i] == num]
    data_y = [y_vals[i] for i in range(len(y)) if y[i] == num]
    data[num] = [data_x, data_y]
    
ax = axs[0]

for num, color, marker, label in zip(data.keys(), colors, markers, labels):
    data_x, data_y = data[num]
    x_idxs = [list(x_vals_u).index(xi) for xi in data_x]
    y_idxs = [list(y_vals_u).index(yi) for yi in data_y]
    ax.scatter(x_idxs, y_idxs, c=color, marker=marker, s=500, label=label)

# ax.legend(loc=(-0.18, 0.1), shadow=True, fontsize=40, frameon=False, handletextpad=-0.5)

# Get the length of x_vals and the mid index
n = len(x_vals_u)
mid = n // 2
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([x_vals_u[0], x_vals_u[mid], x_vals_u[n - 1]], fontsize=40)

n = len(y_vals_u)
mid = n // 2
ax.set_ylabel('Petal width', fontsize=40)
ax.set_yticks([0, mid, n - 1])
ax.set_yticklabels([y_vals_u[0], y_vals_u[mid], y_vals_u[n - 1]], fontsize=40)
ax.set_title('Column 1', fontsize=40)

# Entry (0, 1): the Probability distribution of Petal length for Setosa

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/iris/prob_dists_file/LogisticRegression/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[1]

ax.text(-0.8, 0.8, 'LR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='black', label='LR')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 2', fontsize=40)

# Entry (0, 2): the Probability distribution of Petal length for Versicolor

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/blr/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[2]

ax.text(-0.8, 0.8, 'BLR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='green')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 3', fontsize=40)

# Entry (0, 3): the Probability distribution of Petal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/iris/prob_dists_file/GaussianNB/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[3]

ax.text(-0.8, 0.8, 'GNB', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='magenta')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 4', fontsize=40)

# Entry (0, 0): the scatter plot between Petal width and Petal length

# Get the x values
x_col = features.index('Sepal width')
x_vals = X[:, x_col]
x_vals_u = np.unique(x_vals)

# Get the y values
y_col = features.index('Sepal length')
y_vals = X[:, y_col]
y_vals_u = np.unique(y_vals)

# Get the color, marker, and label
colors = ["red", "green", "blue"]
markers = ["o", "*", "s"]
labels = ["1", "2", "3"]

# Get the data
data = {}
for num in range(3):
    data_x = [x_vals[i] for i in range(len(y)) if y[i] == num]
    data_y = [y_vals[i] for i in range(len(y)) if y[i] == num]
    data[num] = [data_x, data_y]
    
ax = axs[4]

for num, color, marker, label in zip(data.keys(), colors, markers, labels):
    data_x, data_y = data[num]
    x_idxs = [list(x_vals_u).index(xi) for xi in data_x]
    y_idxs = [list(y_vals_u).index(yi) for yi in data_y]
    ax.scatter(x_idxs, y_idxs, c=color, marker=marker, s=500, label=label)

# ax.legend(loc=(-0.18, 0.1), shadow=True, fontsize=40, frameon=False, handletextpad=-0.5)

# Get the length of x_vals and the mid index
n = len(x_vals_u)
mid = n // 2
ax.set_xlabel('Sepal width', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([x_vals_u[0], x_vals_u[mid], x_vals_u[n - 1]], fontsize=40)

n = len(y_vals_u)
mid = n // 2
ax.set_ylabel('Sepal length', fontsize=40)
ax.set_yticks([0, mid, n - 1])
ax.set_yticklabels([y_vals_u[0], y_vals_u[mid], y_vals_u[n - 1]], fontsize=40)
ax.set_title('Column 5', fontsize=40)

# Entry (0, 1): the Probability distribution of Petal length for Setosa

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/iris/prob_dists_file/LogisticRegression/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Sepal width')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[5]

ax.text(-0.8, 0.8, 'LR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='black', label='LR')
ax.set_xlabel('Sepal width', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 6', fontsize=40)

# Entry (0, 2): the Probability distribution of Petal length for Versicolor

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/blr/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Sepal width')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[6]

ax.text(-0.8, 0.8, 'BLR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='green')
ax.set_xlabel('Sepal width', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 7', fontsize=40)

# Entry (0, 3): the Probability distribution of Petal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/iris/prob_dists_file/GaussianNB/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Sepal width')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[7]

ax.text(-0.8, 0.8, 'GNB', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='magenta')
ax.set_xlabel('Sepal width', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 8', fontsize=40)
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/iris_lr_blr_gnb.pdf', dpi=300)
plt.show()

# %% [markdown]
# # Plot Figure 3

# %%
# The file names
file_names = '/Users/yhuang/Desktop/fid/result/blr/breast-cancer-wisconsin/prob_dists_file/breast-cancer-wisconsin.csv'

# The row number
nrows = 1

# The column number
ncols = 9

# The class names
class_names = [4] * ncols

# The feature names
feature_names = ['Uniformity of Cell Size', 
                 'Uniformity of Cell Shape', 
                 'Bare Nuclei',
                 'Single Epithelial Cell Size',
                 'Bland Chromatin',
                 'Normal Nucleoli',
                 'Clump Thickness', 
                 'Marginal Adhesion',
                 'Mitoses'] * 2

# The colors
colors = ['green'] * ncols

# The labels
labels = [None] * nrows * ncols

# The fontsize
fontsize = 40

# The titles
titles = ['Column ' + str(i) for i in range(1, ncols + 1)]

# The xlabels
xlabels = ['U Cell Size', 
'U Cell Shape', 
'Nuclei',
'SE Cell Size',
'Chromatin',
'Nucleoli',
'Clump',
'Adhesion',
'Mitoses']

# The ylabels
ylabels = [None] * nrows * ncols

# The xticks
xticks = [None] * nrows * ncols

# The xticklabels
xticklabels = [None] * ncols

# The decimal places
decimal_places = [None] * nrows * ncols

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, sharey=True, figsize=(32, 4), squeeze=False)

for row in range(nrows):
    for col in range(ncols):
        idx = row * ncols + col
        plot_distribution(row,
                          col,
                          file_names, 
                          class_names[idx], 
                          feature_names[idx], 
                          colors[idx],
                          labels[idx],
                          fontsize,
                          titles[idx],
                          xlabels[idx],
                          ylabels[idx],
                          xticks[idx],
                          xticklabels[idx],
                          decimal_places[idx])
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/breast_cancer_wisconsin_blr.pdf', dpi=300)
plt.show()

# %% [markdown]
# # Plot Figure 4

# %% [markdown]
# ## Load data

# %%
import pandas as pd

# Load the data
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data', header=None)

# Specify the name of the columns
df.columns = ['ID',
'Uniformity of Cell Size', 
'Uniformity of Cell Shape', 
'Bare Nuclei',
'Single Epithelial Cell Size',
'Bland Chromatin',
'Normal Nucleoli',
'Clump Thickness', 
'Marginal Adhesion',
'Mitoses',
'Class']

# Features
features = ['Uniformity of Cell Size', 
'Uniformity of Cell Shape', 
'Bare Nuclei',
'Single Epithelial Cell Size',
'Bland Chromatin',
'Normal Nucleoli',
'Clump Thickness', 
'Marginal Adhesion',
'Mitoses']

# Get the features
X = df[features].values

# Get the target
y = df['Class'].values

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# The label encoder for the target
le = LabelEncoder()

# Encode the target
y = le.fit_transform(y)

# %% [markdown]
# ## The 1 $\times$ 4 matrix

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(22, 5))

# Entry (0, 0): the scatter plot between Petal width and Petal length

# Get the x values
x_col = features.index('Mitoses')
x_vals = X[:, x_col]
x_vals_u = np.unique(x_vals)

# Get the y values
y_col = features.index('Marginal Adhesion')
y_vals = X[:, y_col]
y_vals_u = np.unique(y_vals)

# Get the color, marker, and label
colors = ["red", "green"]
markers = ["o", "*"]
labels = ["2", "4"]

# Get the data
data = {}
for num in range(2):
    data_x = [x_vals[i] for i in range(len(y)) if y[i] == num]
    data_y = [y_vals[i] for i in range(len(y)) if y[i] == num]
    data[num] = [data_x, data_y]
    
ax = axs[0]

for num, color, marker, label in zip(data.keys(), colors, markers, labels):
    data_x, data_y = data[num]
    x_idxs = [list(x_vals_u).index(xi) for xi in data_x]
    y_idxs = [list(y_vals_u).index(yi) for yi in data_y]
    ax.scatter(x_idxs, y_idxs, c=color, marker=marker, s=500, label=label)

# ax.legend(loc=(-0.18, 0.1), shadow=True, fontsize=40, frameon=False, handletextpad=-0.5)

# Get the length of x_vals and the mid index
n = len(x_vals_u)
mid = n // 2
ax.set_xlabel('Mitoses', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([x_vals_u[0], x_vals_u[mid], x_vals_u[n - 1]], fontsize=40)

n = len(y_vals_u)
mid = n // 2
ax.set_ylabel('Adhesion', fontsize=40)
ax.set_yticks([0, mid, n - 1])
ax.set_yticklabels([y_vals_u[0], y_vals_u[mid], y_vals_u[n - 1]], fontsize=40)
ax.set_title('Column 1', fontsize=40)

# Entry (0, 1): the Probability distribution of Petal length for Setosa

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/breast-cancer-wisconsin/prob_dists_file/LogisticRegression/breast-cancer-wisconsin.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 4) & (df['xj'] == 'Mitoses')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[1]

ax.text(-0.8, 0.8, 'LR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='black', label='LR')
ax.set_xlabel('Mitoses', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([int(xijs[0]), int(xijs[mid]), int(xijs[n - 1])], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 2', fontsize=40)

# Entry (0, 2): the Probability distribution of Petal length for Versicolor

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/blr/breast-cancer-wisconsin/prob_dists_file/breast-cancer-wisconsin.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 4) & (df['xj'] == 'Mitoses')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[2]

ax.text(-0.8, 0.8, 'BLR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='green')
ax.set_xlabel('Mitoses', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([int(xijs[0]), int(xijs[mid]), int(xijs[n - 1])], fontsize=40)

ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 3', fontsize=40)

# Entry (0, 3): the Probability distribution of Petal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/breast-cancer-wisconsin/prob_dists_file/GaussianNB/breast-cancer-wisconsin.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 4) & (df['xj'] == 'Mitoses')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[3]

ax.text(-0.8, 0.8, 'GNB', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='magenta')
ax.set_xlabel('Mitoses', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([int(xijs[0]), int(xijs[mid]), int(xijs[n - 1])], fontsize=40)

ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 4', fontsize=40)
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/breast_cancer_wisconsin_lr_blr_gnb.pdf', dpi=300)
plt.show()

# %% [markdown]
# # Plot Figure 5

# %%
file_names = '/Users/yhuang/Desktop/fid/result/blr/parkinsons/prob_dists_file/parkinsons.csv'

# The row number
nrows = 1

# The column number
ncols = 11

# The class names
class_names = [0] * ncols + [1] * ncols

# The feature names
feature_names = ['MDVP:Jitter(%)', 
                 'MDVP:Jitter(Abs)', 
                 'MDVP:RAP', 
                 'MDVP:PPQ',
                 'Jitter:DDP',
                 'MDVP:Shimmer(dB)',
                 'MDVP:APQ',
                 'MDVP:Shimmer',
                 'Shimmer:APQ3',
                 'Shimmer:APQ5',
                 'Shimmer:DDA'] * 2

# The colors
colors = ['green'] * ncols

# The labels
labels = [None] * nrows * ncols

# The fontsize
fontsize = 40

# The titles
titles = ['Column ' + str(i) for i in range(1, ncols + 1)]

# The xlabels
xlabels = feature_names

# The ylabels
ylabels = [None] * nrows * ncols

# The xticks
xticks = [None] * nrows * ncols

# The xticklabels
xticklabels = [None] + [[0.0, 0.0003]] + [None] * (ncols -2)

# The decimal places
decimal_places = [2] * nrows * ncols

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, sharey=True, figsize=(52, 4.6), squeeze=False)

for row in range(nrows):
    for col in range(ncols):
        idx = row * ncols + col
        plot_distribution(row,
                          col,
                          file_names, 
                          class_names[idx], 
                          feature_names[idx], 
                          colors[idx],
                          labels[idx],
                          fontsize,
                          titles[idx],
                          xlabels[idx],
                          ylabels[idx],
                          xticks[idx],
                          xticklabels[idx],
                          decimal_places[idx])
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/parkinsons_blr.pdf', dpi=300)
plt.show()

# %% [markdown]
# # Plot Figure 6

# %% [markdown]
# ## Load data

# %%
import pandas as pd

# Load the data
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/parkinsons.data', header=0)

# Features
features = ['name',
 'MDVP:Fo(Hz)',
 'MDVP:Fhi(Hz)',
 'MDVP:Flo(Hz)',
 'MDVP:Jitter(%)',
 'MDVP:Jitter(Abs)',
 'MDVP:RAP',
 'MDVP:PPQ',
 'Jitter:DDP',
 'MDVP:Shimmer',
 'MDVP:Shimmer(dB)',
 'Shimmer:APQ3',
 'Shimmer:APQ5',
 'MDVP:APQ',
 'Shimmer:DDA',
 'NHR',
 'HNR',
 'RPDE',
 'DFA',
 'spread1',
 'spread2',
 'D2',
 'PPE']

# Get the features
X = df[features].values

# Get the target
y = df['status'].values

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
import math

# The label encoder for the target
le = LabelEncoder()

# Encode the target
y = le.fit_transform(y)

# %% [markdown]
# ## The 1 $\times$ 4 matrix

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(22, 5))

# Entry (0, 0): the scatter plot between Petal width and Petal length

# Get the x values
x_col = features.index('Shimmer:APQ5')
x_vals = X[:, x_col]
x_vals_u = np.unique(x_vals)

# Get the y values
y_col = features.index('Shimmer:APQ3')
y_vals = X[:, y_col]
y_vals_u = np.unique(y_vals)

# Get the color, marker, and label
colors = ["red", "green"]
markers = ["o", "*"]
labels = ["0", "1"]

# Get the data
data = {}
for num in range(2):
    data_x = [x_vals[i] for i in range(len(y)) if y[i] == num]
    data_y = [y_vals[i] for i in range(len(y)) if y[i] == num]
    data[num] = [data_x, data_y]
    
ax = axs[0]

for num, color, marker, label in zip(data.keys(), colors, markers, labels):
    data_x, data_y = data[num]
    x_idxs = [list(x_vals_u).index(xi) for xi in data_x]
    y_idxs = [list(y_vals_u).index(yi) for yi in data_y]
    ax.scatter(x_idxs, y_idxs, c=color, marker=marker, s=500, label=label)

# ax.legend(loc=(-0.18, 0.1), shadow=True, fontsize=40, frameon=False, handletextpad=-0.5)

# Get the length of x_vals and the mid index
n = len(x_vals_u)
mid = n // 2
ax.set_xlabel('Shimmer:APQ5', fontsize=40)
ax.set_xticks([0, n - 1])
ax.set_xticklabels([round(x_vals_u[0], 2), round(x_vals_u[n - 1], 2)], fontsize=40)

n = len(y_vals_u)
mid = n // 2
ax.set_ylabel('Shimmer:APQ3', fontsize=40)
ax.set_yticks([0, n - 1])
ax.set_yticklabels([round(y_vals_u[0], 2), round(y_vals_u[n - 1], 2)], fontsize=40)
ax.set_title('Column 1', fontsize=40)

# Entry (0, 1): the Probability distribution of Petal length for Setosa

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/parkinsons/prob_dists_file/LogisticRegression/parkinsons.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 1) & (df['xj'] == 'Shimmer:APQ5')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[1]

ax.text(-0.8, 0.8, 'LR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='black', label='LR')
ax.set_xlabel('Shimmer:APQ5', fontsize=40)
ax.set_xticks([0, n - 1])
ax.set_xticklabels([round(xijs[0], 2), round(xijs[n - 1], 2)], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 2', fontsize=40)

# Entry (0, 2): the Probability distribution of Petal length for Versicolor

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/blr/parkinsons/prob_dists_file/parkinsons.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 1) & (df['xj'] == 'Shimmer:APQ5')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[2]

ax.text(-0.8, 0.8, 'BLR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='green')
ax.set_xlabel('Shimmer:APQ5', fontsize=40)
ax.set_xticks([0, n - 1])
ax.set_xticklabels([round(xijs[0], 2), round(xijs[n - 1], 2)], fontsize=40)

ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 3', fontsize=40)

# Entry (0, 3): the Probability distribution of Petal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/parkinsons/prob_dists_file/GaussianNB/parkinsons.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 1) & (df['xj'] == 'Shimmer:APQ5')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[3]

ax.text(-0.8, 0.8, 'GNB', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='magenta')
ax.set_xlabel('Shimmer:APQ5', fontsize=40)
ax.set_xticks([0, n - 1])
ax.set_xticklabels([round(xijs[0], 2), round(xijs[n - 1], 2)], fontsize=40)

ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 4', fontsize=40)
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/parkinsons_lr_blr_gnb.pdf', dpi=300)
plt.show()

# %% [markdown]
# # Plot Figure 7

# %%
# The file names
drugs = 'Amphet, Amyl, Benzos, Coke, Ecstasy, Legalh, LSD, Mushrooms, Nicotine'.split(',')
file_names = ['/Users/yhuang/Desktop/fid/result/blr/drug_consumption/'+ drug.strip() + '/prob_dists_file/drug_consumption.csv'for drug in drugs] * 2

# The row number
nrows = 1

# The column number
ncols = 9

# The class names
class_names = ['CL7'] * ncols

# The feature names
feature_names = ['Impulsive'] * 2 * ncols

# The colors
colors = ['green'] * ncols

# The labels
labels = [None] * nrows * ncols

# The fontsize
fontsize = 40

# The titles
titles = drugs

# The xlabels
xlabels = [None] * nrows * ncols

# The ylabels
ylabels = [None] * nrows * ncols

# The xticks
xticks = [None] * nrows * ncols

# The xticklabels
xticklabels = [None] * ncols

# The decimal places
decimal_places = [1] * nrows * ncols

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, sharey=True, figsize=(28, 3), squeeze=False)

for row in range(nrows):
    for col in range(ncols):
        idx = row * ncols + col
        plot_distribution(row,
                          col,
                          file_names[idx], 
                          class_names[idx], 
                          feature_names[idx], 
                          colors[idx],
                          labels[idx],
                          fontsize,
                          titles[idx],
                          xlabels[idx],
                          ylabels[idx],
                          xticks[idx],
                          xticklabels[idx],
                          decimal_places[idx])
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/drug_consumption_blr_impulsive_noninformative.pdf', dpi=300)
plt.show()

# %%
# The file names
drugs = 'Alcohol, Caff, Cannabis, Choc, Crack, Heroin, Ketamine, Meth, Semer, VSA'.split(',')
file_names = ['/Users/yhuang/Desktop/fid/result/blr/drug_consumption/'+ drug.strip() + '/prob_dists_file/drug_consumption.csv'for drug in drugs] * 2

# The row number
nrows = 1

# The column number
ncols = 10

# The class names
class_names = ['CL7'] * ncols

# The feature names
feature_names = ['Impulsive'] * 2 * ncols

# The colors
colors = ['green'] * ncols

# The labels
labels = [None] * nrows * ncols

# The fontsize
fontsize = 40

# The titles
titles = drugs

# The xlabels
xlabels = [None] * nrows * ncols

# The ylabels
ylabels = [None] * nrows * ncols

# The xticks
xticks = [None] * nrows * ncols

# The xticklabels
xticklabels = [None] * ncols

# The decimal places
decimal_places = [1] * nrows * ncols

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, sharey=True, figsize=(30, 3.2), squeeze=False)

for row in range(nrows):
    for col in range(ncols):
        idx = row * ncols + col
        plot_distribution(row,
                          col,
                          file_names[idx], 
                          class_names[idx], 
                          feature_names[idx], 
                          colors[idx],
                          labels[idx],
                          fontsize,
                          titles[idx],
                          xlabels[idx],
                          ylabels[idx],
                          xticks[idx],
                          xticklabels[idx],
                          decimal_places[idx])
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/drug_consumption_blr_impulsive_informative.pdf', dpi=300)
plt.show()

# %% [markdown]
# # Plot Figure 8

# %% [markdown]
# ## Load data

# %%
import pandas as pd

# Load the data
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00373/drug_consumption.data', header=None)

# Specify the name of the columns
df.columns = ['ID',
 'Age',
 'Gender',
 'Education',
 'Country',
 'Ethnicity',
 'Nscore',
 'Escore',
 'Oscore',
 'Ascore',
 'Cscore',
 'Impulsive',
 'SS',
 'Alcohol',
 'Amphet',
 'Amyl',
 'Benzos',
 'Caff',
 'Cannabis',
 'Choc',
 'Coke',
 'Crack',
 'Ecstasy',
 'Heroin',
 'Ketamine',
 'Legalh',
 'LSD',
 'Meth',
 'Mushrooms',
 'Nicotine',
 'Semer',
 'VSA']

# Features
features = ['Age',
 'Gender',
 'Education',
 'Country',
 'Ethnicity',
 'Nscore',
 'Escore',
 'Oscore',
 'Ascore',
 'Cscore',
 'Impulsive',
 'SS']

# Combine CL1 to CL6 into CL7
for i in range(1, 7):
    df = df.replace('CL' + str(i), 'CL7')

# Get the features
X = df[features].values

# Get the target
y = df['Alcohol'].values

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
import math

# The label encoder for the target
le = LabelEncoder()

# Encode the target
y = le.fit_transform(y)

# %% [markdown]
# ## The 1 $\times$ 4 matrix

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(22, 5))

# Entry (0, 0): the scatter plot between Petal width and Petal length

# Get the x values
x_col = features.index('Impulsive')
x_vals = X[:, x_col]
x_vals_u = np.unique(x_vals)

# Get the y values
y_col = features.index('SS')
y_vals = X[:, y_col]
y_vals_u = np.unique(y_vals)

# Get the color, marker, and label
colors = ["red", "green"]
markers = ["o", "*"]
labels = ["0", "1"]

# Get the data
data = {}
for num in range(2):
    data_x = [x_vals[i] for i in range(len(y)) if y[i] == num]
    data_y = [y_vals[i] for i in range(len(y)) if y[i] == num]
    data[num] = [data_x, data_y]
    
ax = axs[0]

for num, color, marker, label in zip(data.keys(), colors, markers, labels):
    data_x, data_y = data[num]
    x_idxs = [list(x_vals_u).index(xi) for xi in data_x]
    y_idxs = [list(y_vals_u).index(yi) for yi in data_y]
    ax.scatter(x_idxs, y_idxs, c=color, marker=marker, s=500, label=label)

# ax.legend(loc=(-0.18, 0.1), shadow=True, fontsize=40, frameon=False, handletextpad=-0.5)

# Get the length of x_vals and the mid index
n = len(x_vals_u)
mid = n // 2
ax.set_xlabel('Impulsive', fontsize=40)
ax.set_xticks([0, n - 1])
ax.set_xticklabels([round(x_vals_u[0], 1), round(x_vals_u[n - 1], 1)], fontsize=40)

n = len(y_vals_u)
mid = n // 2
ax.set_ylabel('SS', fontsize=40)
ax.set_yticks([0, n - 1])
ax.set_yticklabels([round(y_vals_u[0], 1), round(y_vals_u[n - 1], 1)], fontsize=40)
ax.set_title('Column 1', fontsize=40)

# Entry (0, 1): the Probability distribution of Petal length for Setosa

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/drug_consumption/Alcohol/prob_dists_file/LogisticRegression/drug_consumption.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'CL7') & (df['xj'] == 'Impulsive')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[1]

ax.text(-0.8, 0.8, 'LR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='black', label='LR')
ax.set_xlabel('Impulsive', fontsize=40)
ax.set_xticks([0, n - 1])
ax.set_xticklabels([round(xijs[0], 1), round(xijs[n - 1], 1)], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 2', fontsize=40)

# Entry (0, 2): the Probability distribution of Petal length for Versicolor

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/blr/drug_consumption/Alcohol/prob_dists_file/drug_consumption.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'CL7') & (df['xj'] == 'Impulsive')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[2]

ax.text(-0.8, 0.8, 'BLR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='green')
ax.set_xlabel('Impulsive', fontsize=40)
ax.set_xticks([0, n - 1])
ax.set_xticklabels([round(xijs[0], 1), round(xijs[n - 1], 1)], fontsize=40)

ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 3', fontsize=40)

# Entry (0, 3): the Probability distribution of Petal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/drug_consumption/Alcohol/prob_dists_file/GaussianNB/drug_consumption.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'CL7') & (df['xj'] == 'Impulsive')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[3]

ax.text(-0.8, 0.8, 'GNB', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='magenta')
ax.set_xlabel('Impulsive', fontsize=40)
ax.set_xticks([0, n - 1])
ax.set_xticklabels([round(xijs[0], 1), round(xijs[n - 1], 1)], fontsize=40)

ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 4', fontsize=40)
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/drug_consumption_lr_blr_gnb.pdf', dpi=300)
plt.show()
