# %% [markdown]
# # Plot Figure 1

# %% [markdown]
# ## Load data

# %%
import pandas as pd

# Load the data
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)

# Specify the name of the columns
df.columns = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Class']

# Features
features = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width']

# Get the features
X = df[features].values

# Get the target
y = df['Class'].values

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# The label encoder for the target
le = LabelEncoder()

# Encode the target
y = le.fit_transform(y)

# %% [markdown]
# ## Create the figure folder

# %%
import os

# Make directory
directory = os.path.dirname('/Users/yhuang/Desktop/fid/result/figure/')
if not os.path.exists(directory):
    os.makedirs(directory)

# %% [markdown]
# ## The 2 $\times$ 4 matrix

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(nrows=1, ncols=8, figsize=(44, 4.5))

# Entry (0, 0): the scatter plot between Petal width and Petal length

# Get the x values
x_col = features.index('Petal length')
x_vals = X[:, x_col]
x_vals_u = np.unique(x_vals)

# Get the y values
y_col = features.index('Petal width')
y_vals = X[:, y_col]
y_vals_u = np.unique(y_vals)

# Get the color, marker, and label
colors = ["red", "green", "blue"]
markers = ["o", "*", "s"]
labels = ["1", "2", "3"]

# Get the data
data = {}
for num in range(3):
    data_x = [x_vals[i] for i in range(len(y)) if y[i] == num]
    data_y = [y_vals[i] for i in range(len(y)) if y[i] == num]
    data[num] = [data_x, data_y]
    
ax = axs[0]

for num, color, marker, label in zip(data.keys(), colors, markers, labels):
    data_x, data_y = data[num]
    x_idxs = [list(x_vals_u).index(xi) for xi in data_x]
    y_idxs = [list(y_vals_u).index(yi) for yi in data_y]
    ax.scatter(x_idxs, y_idxs, c=color, marker=marker, s=200, label=label)

ax.legend(loc=(-0.18, 0.1), shadow=True, fontsize=40, frameon=False, handletextpad=-0.5)

# Get the length of x_vals and the mid index
n = len(x_vals_u)
mid = n // 2
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([x_vals_u[0], x_vals_u[mid], x_vals_u[n - 1]], fontsize=40)

n = len(y_vals_u)
mid = n // 2
ax.set_ylabel('Petal width', fontsize=40)
ax.set_yticks([0, mid, n - 1])
ax.set_yticklabels([y_vals_u[0], y_vals_u[mid], y_vals_u[n - 1]], fontsize=40)
ax.set_title('Column 1', fontsize=40)

# Entry (0, 1): the importance distribution of Petal length for Setosa

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/ours/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-setosa') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[1]

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='red')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Importance', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 2', fontsize=40)

# Entry (0, 2): the importance distribution of Petal length for Versicolor

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/ours/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[2]

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='green')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

# ax.set_ylabel('Importance', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 3', fontsize=40)

# Entry (0, 3): the importance distribution of Petal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/ours/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-virginica') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[3]

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='blue')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

# ax.set_ylabel('Importance', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 4', fontsize=40)

# Entry (1, 0): the scatter plot between Sepal width and Sepal length

# Get the x values
x_col = features.index('Sepal length')
x_vals = X[:, x_col]
x_vals_u = np.unique(x_vals)

# Get the y values
y_col = features.index('Sepal width')
y_vals = X[:, y_col]
y_vals_u = np.unique(y_vals)

# Get the color, marker, and label
colors = ["red", "green", "blue"]
markers = ["o", "*", "s"]
labels = ["1", "2", "3"]

# Get the data
data = {}
for num in range(3):
    data_x = [x_vals[i] for i in range(len(y)) if y[i] == num]
    data_y = [y_vals[i] for i in range(len(y)) if y[i] == num]
    data[num] = [data_x, data_y]
    
ax = axs[4]

for num, color, marker, label in zip(data.keys(), colors, markers, labels):
    data_x, data_y = data[num]
    x_idxs = [list(x_vals_u).index(xi) for xi in data_x]
    y_idxs = [list(y_vals_u).index(yi) for yi in data_y]
    ax.scatter(x_idxs, y_idxs, c=color, marker=marker, s=200, label=label)
    
# Get the length of x_vals and the mid index
n = len(x_vals_u)
mid = n // 2
ax.set_xlabel('Sepal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([x_vals_u[0], x_vals_u[mid], x_vals_u[n - 1]], fontsize=40)

n = len(y_vals_u)
mid = n // 2
ax.set_ylabel('Sepal width', fontsize=40)
ax.set_yticks([0, mid, n - 1])
ax.set_yticklabels([y_vals_u[0], y_vals_u[mid], y_vals_u[n - 1]], fontsize=40)
ax.set_title('Column 5', fontsize=40)

# Entry (1, 1): the importance distribution of Sepal length for Setosa

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/ours/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-setosa') & (df['xj'] == 'Sepal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[5]

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='red')
ax.set_xlabel('Sepal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Importance', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 6', fontsize=40)

# Entry (1, 2): the importance distribution of Sepal length for Versicolor

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/ours/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Sepal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[6]

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='green')
ax.set_xlabel('Sepal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

# ax.set_ylabel('Importance', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 7', fontsize=40)

# Entry (1, 3): the importance distribution of Sepal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/ours/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-virginica') & (df['xj'] == 'Sepal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[7]

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='blue')
ax.set_xlabel('Sepal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

# ax.set_ylabel('Importance', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 8', fontsize=40)

fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/iris_fid.pdf', dpi=300)
plt.show()

# %% [markdown]
# # The plot distribution function

# %%
def plot_distribution(row, col, file_name, class_name, feature_name, color, label, fontsize, title, xlabel, ylabel, xticks, xticklabels, decimal_place):    
    # Load the distribution file
    df = pd.read_csv(file_name, header=0)
    
    # Specify the name of the columns
    df.columns = ['yu', 'xj', 'xij', 'pij']
    
    df = df.loc[(df['yu'] == class_name) & (df['xj'] == feature_name)]

    # Get the feature values
    xijs = df['xij'].values

    # Get the probabilities
    pijs = df['pij'].values

    ax = axs[row][col]
    
    # Plot the bar chart
    ax.bar(range(len(xijs)), pijs, color=color, label=label)
    
    if label is not None:
        ax.legend(fontsize=fontsize)
        
    if title is not None:
        ax.set_title(title, fontsize=fontsize)
        
    if xlabel is not None:
        ax.set_xlabel(xlabel, fontsize=fontsize)
        
    if ylabel is not None:
        ax.set_ylabel(ylabel, fontsize=fontsize)

    n = len(xijs)
    if xticks is None:
        ax.set_xticks([0, n - 1])
    else:
        ax.set_xticks(xticks)

    if xticklabels is None:
        ax.set_xticklabels([round(xijs[0], decimal_place) if decimal_place is not None else int(xijs[0]),
                            round(xijs[n - 1], decimal_place) if decimal_place is not None else int(xijs[n - 1])], 
                           fontsize=fontsize)     
    else:
        ax.set_xticklabels(xticklabels, fontsize=fontsize)
        
    ax.set_ylim([0, 1])
    ax.set_yticks([0, 1])
    ax.set_yticklabels([0, 1], fontsize=fontsize)

# %% [markdown]
# # Plot Figure 2

# %%
fig, axs = plt.subplots(nrows=1, ncols=10, figsize=(52, 4.5))

# Entry (0, 0): the scatter plot between Petal width and Petal length

# Get the x values
x_col = features.index('Petal length')
x_vals = X[:, x_col]
x_vals_u = np.unique(x_vals)

# Get the y values
y_col = features.index('Petal width')
y_vals = X[:, y_col]
y_vals_u = np.unique(y_vals)

# Get the color, marker, and label
colors = ["red", "green", "blue"]
markers = ["o", "*", "s"]
labels = ["1", "2", "3"]

# Get the data
data = {}
for num in range(3):
    data_x = [x_vals[i] for i in range(len(y)) if y[i] == num]
    data_y = [y_vals[i] for i in range(len(y)) if y[i] == num]
    data[num] = [data_x, data_y]
    
ax = axs[0]

for num, color, marker, label in zip(data.keys(), colors, markers, labels):
    data_x, data_y = data[num]
    x_idxs = [list(x_vals_u).index(xi) for xi in data_x]
    y_idxs = [list(y_vals_u).index(yi) for yi in data_y]
    ax.scatter(x_idxs, y_idxs, c=color, marker=marker, s=200, label=label)

ax.legend(loc=(-0.18, 0.1), shadow=True, fontsize=40, frameon=False, handletextpad=-0.5)

# Get the length of x_vals and the mid index
n = len(x_vals_u)
mid = n // 2
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([x_vals_u[0], x_vals_u[mid], x_vals_u[n - 1]], fontsize=40)

n = len(y_vals_u)
mid = n // 2
ax.set_ylabel('Petal width', fontsize=40)
ax.set_yticks([0, mid, n - 1])
ax.set_yticklabels([y_vals_u[0], y_vals_u[mid], y_vals_u[n - 1]], fontsize=40)
ax.set_title('Column 1', fontsize=40)

# Entry (0, 1): the importance distribution of Petal length for Setosa

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/iris/prob_dists_file/LogisticRegression/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[1]

ax.text(-0.8, 0.8, 'LR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='black', label='LR')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 2', fontsize=40)

# Entry (0, 2): the importance distribution of Petal length for Versicolor

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/blr/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[2]

ax.text(-0.8, 0.8, 'BLR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='chocolate')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 3', fontsize=40)

# Entry (0, 3): the importance distribution of Petal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/iris/prob_dists_file/GaussianNB/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[3]

ax.text(-0.8, 0.8, 'GNB', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='magenta')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 4', fontsize=40)

# Entry (0, 4): the importance distribution of Petal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/ours/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Petal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[4]

ax.text(-0.8, 0.8, 'FID', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='green')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Importance', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 5', fontsize=40)

# Entry (1, 0): the scatter plot between Sepal width and Sepal length

# Get the x values
x_col = features.index('Sepal length')
x_vals = X[:, x_col]
x_vals_u = np.unique(x_vals)

# Get the y values
y_col = features.index('Sepal width')
y_vals = X[:, y_col]
y_vals_u = np.unique(y_vals)

# Get the color, marker, and label
colors = ["red", "green", "blue"]
markers = ["o", "*", "s"]
labels = ["1", "2", "3"]

# Get the data
data = {}
for num in range(3):
    data_x = [x_vals[i] for i in range(len(y)) if y[i] == num]
    data_y = [y_vals[i] for i in range(len(y)) if y[i] == num]
    data[num] = [data_x, data_y]
    
ax = axs[5]

for num, color, marker, label in zip(data.keys(), colors, markers, labels):
    data_x, data_y = data[num]
    x_idxs = [list(x_vals_u).index(xi) for xi in data_x]
    y_idxs = [list(y_vals_u).index(yi) for yi in data_y]
    ax.scatter(x_idxs, y_idxs, c=color, marker=marker, s=200, label=label)
    
# Get the length of x_vals and the mid index
n = len(x_vals_u)
mid = n // 2
ax.set_xlabel('Sepal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([x_vals_u[0], x_vals_u[mid], x_vals_u[n - 1]], fontsize=40)

n = len(y_vals_u)
mid = n // 2
ax.set_ylabel('Sepal width', fontsize=40)
ax.set_yticks([0, mid, n - 1])
ax.set_yticklabels([y_vals_u[0], y_vals_u[mid], y_vals_u[n - 1]], fontsize=40)
ax.set_title('Column 6', fontsize=40)

# Entry (1, 1): the importance distribution of Sepal length for Setosa

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/iris/prob_dists_file/LogisticRegression/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Sepal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[6]

ax.text(-0.8, 0.8, 'LR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='black')
ax.set_xlabel('Sepal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 7', fontsize=40)

# Entry (1, 2): the importance distribution of Sepal length for Versicolor

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/blr/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Sepal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[7]

ax.text(-0.8, 0.8, 'BLR', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='chocolate')
ax.set_xlabel('Sepal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 8', fontsize=40)

# Entry (1, 3): the importance distribution of Sepal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/others/iris/prob_dists_file/GaussianNB/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Sepal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[8]

ax.text(-0.8, 0.8, 'GNB', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='magenta')
ax.set_xlabel('Sepal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Probability', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 9', fontsize=40)

# Entry (1, 4): the importance distribution of Petal length for Virginca

# Load the distribution file
df = pd.read_csv('/Users/yhuang/Desktop/fid/result/ours/iris/prob_dists_file/iris.csv', header=0)

# Specify the name of the columns
df.columns = ['yu', 'xj', 'xij', 'pij']

df = df.loc[(df['yu'] == 'Iris-versicolor') & (df['xj'] == 'Sepal length')]

# Get the feature values
xijs = df['xij'].values

# Get the probabilities
pijs = df['pij'].values

ax = axs[9]

ax.text(-0.8, 0.8, 'FID', fontsize=40)

# Get the length of x_vals and the mid index
n = len(xijs)
mid = n // 2
# Plot the bar chart
ax.bar(range(len(xijs)), pijs, color='green')
ax.set_xlabel('Petal length', fontsize=40)
ax.set_xticks([0, mid, n - 1])
ax.set_xticklabels([xijs[0], xijs[mid], xijs[n - 1]], fontsize=40)

ax.set_ylabel('Importance', fontsize=40)
ax.set_ylim([0, 1])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, 0.5, 1], fontsize=40)
ax.set_title('Column 10', fontsize=40)
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/iris_lr_blr_gnb_fid.pdf', dpi=300)
plt.show()

# %% [markdown]
# # Plot Figure 3

# %%
# The file names
file_names = '/Users/yhuang/Desktop/fid/result/ours/breast-cancer-wisconsin/prob_dists_file/breast-cancer-wisconsin.csv'

# The row number
nrows = 2

# The column number
ncols = 9

# The class names
class_names = [2] * ncols + [4] * ncols

# The feature names
feature_names = ['Uniformity of Cell Size', 
                 'Uniformity of Cell Shape', 
                 'Bare Nuclei',
                 'Single Epithelial Cell Size',
                 'Bland Chromatin',
                 'Normal Nucleoli',
                 'Clump Thickness', 
                 'Marginal Adhesion',
                 'Mitoses'] * 2

# The colors
colors = ['green'] * ncols + ['red'] * ncols

# The labels
labels = [None] * nrows * ncols

# The fontsize
fontsize = 40

# The titles
titles = ['Column ' + str(i) for i in range(1, ncols + 1)] + [None] * ncols

# The xlabels
xlabels = [None] * ncols + ['U Cell Size', 
                            'U Cell Shape', 
                            'Nuclei',
                            'SE Cell Size',
                            'Chromatin',
                            'Nucleoli',
                            'Clump',
                            'Adhesion',
                            'Mitoses']

# The ylabels
ylabels = [None] * nrows * ncols

# The xticks
xticks = [None] * nrows * ncols

# The xticklabels
xticklabels = [[]] * ncols + [None] * ncols

# The decimal places
decimal_places = [None] * nrows * ncols

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, sharey=True, figsize=(30, 6), squeeze=False)

for row in range(nrows):
    for col in range(ncols):
        idx = row * ncols + col
        plot_distribution(row,
                          col,
                          file_names, 
                          class_names[idx], 
                          feature_names[idx], 
                          colors[idx],
                          labels[idx],
                          fontsize,
                          titles[idx],
                          xlabels[idx],
                          ylabels[idx],
                          xticks[idx],
                          xticklabels[idx],
                          decimal_places[idx])
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/breast_cancer_wisconsin_fid.pdf', dpi=300)
plt.show()

# %% [markdown]
# # The plot importance function

# %%
def plot_importance(file_name, feature_name_display, color):    
    # Load the importance file
    df = pd.read_csv(file_name, header=0).sort_values(by='Importance', ascending=False)
    
    # Specify the name of the columns
    df.columns = ['no', 'xj', 'pij']
    
    # Get the features
    xjs = [feature_name_display[feature_name] for feature_name in df['xj'].values]
    
    # Get the probabilities
    pijs = df['pij'].values

    ax = axs[0][0]
    
    fontsize=35
        
    # Plot the bar chart
    ax.bar(range(len(xjs)), pijs, color=color)
    ax.set_xticks(range(len(xjs)))
    ax.set_xticklabels(xjs, fontsize=fontsize, rotation=90)
    ax.set_ylabel('Importance', fontsize=fontsize)
    ax.set_ylim([0, 0.5])
    ax.set_yticks([0, 0.5])
    ax.set_yticklabels([0, 0.5], fontsize=fontsize)
    ax.set_title('Column 10', fontsize=fontsize)

# %% [markdown]
# # Plot Figure 7

# %%
# The file names
file_name = '/Users/yhuang/Desktop/fid/result/others/breast-cancer-wisconsin/feature_importances_file/RandomForestClassifier/breast-cancer-wisconsin.csv'

# The feature names for display
feature_names_display = {'Uniformity of Cell Size': 'U Cell Size', 
                         'Uniformity of Cell Shape': 'U Cell Shape',  
                         'Bare Nuclei': 'Nuclei',
                         'Single Epithelial Cell Size': 'SE Cell Size',
                         'Bland Chromatin': 'Chromatin',
                         'Normal Nucleoli': 'Nucleoli',
                         'Clump Thickness': 'Clump',
                         'Marginal Adhesion': 'Adhesion',
                         'Mitoses': 'Mitoses'}

# The xticks for display
xticks_display = None

# The colors
color = ['purple']

fig, axs = plt.subplots(nrows=1, ncols=1, sharey=True, figsize=(15, 6), squeeze=False)

plot_importance(file_name, 
                feature_names_display, 
                color)
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/breast_cancer_wisconsin_rf.pdf', dpi=300)
plt.show()

# %% [markdown]
# # Plot Figure 5

# %%
file_names = '/Users/yhuang/Desktop/fid/result/ours/parkinsons/prob_dists_file/parkinsons.csv'

# The row number
nrows = 2

# The column number
ncols = 11

# The class names
class_names = [0] * ncols + [1] * ncols

# The feature names
feature_names = ['MDVP:Jitter(%)', 
                 'MDVP:Jitter(Abs)', 
                 'MDVP:RAP', 
                 'MDVP:PPQ',
                 'Jitter:DDP',
                 'MDVP:Shimmer(dB)',
                 'MDVP:APQ',
                 'MDVP:Shimmer',
                 'Shimmer:APQ3',
                 'Shimmer:APQ5',
                 'Shimmer:DDA'] * 2

# The colors
colors = ['green'] * ncols + ['red'] * ncols

# The labels
labels = [None] * nrows * ncols

# The fontsize
fontsize = 40

# The titles
titles = ['Column ' + str(i) for i in range(1, ncols + 1)] + [None] * ncols

# The xlabels
xlabels = [None] * ncols + feature_names

# The ylabels
ylabels = [None] * nrows * ncols

# The xticks
xticks = [None] * nrows * ncols

# The xticklabels
xticklabels = [[]] * ncols + [None] + [[0.0, 0.0003]] + [None] * (ncols -2)

# The decimal places
decimal_places = [2] * nrows * ncols

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, sharey=True, figsize=(52, 7), squeeze=False)

for row in range(nrows):
    for col in range(ncols):
        idx = row * ncols + col
        plot_distribution(row,
                          col,
                          file_names, 
                          class_names[idx], 
                          feature_names[idx], 
                          colors[idx],
                          labels[idx],
                          fontsize,
                          titles[idx],
                          xlabels[idx],
                          ylabels[idx],
                          xticks[idx],
                          xticklabels[idx],
                          decimal_places[idx])
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/parkinsons_fid.pdf', dpi=300)
plt.show()

# %% [markdown]
# # Plot Figure 6

# %%
# The file names
drugs = 'Amphet, Benzos, Cannabis, Coke, Heroin, Ketamine, Legalh, LSD, Meth, Mushrooms'.split(',')
file_names = ['/Users/yhuang/Desktop/fid/result/ours/drug_consumption/'+ drug.strip() + '/prob_dists_file/drug_consumption.csv'for drug in drugs] * 2

# The row number
nrows = 2

# The column number
ncols = 10

# The class names
class_names = ['CL0'] * ncols + ['CL7'] * ncols

# The feature names
feature_names = ['Impulsive'] * 2 * ncols

# The colors
colors = ['green'] * ncols + ['red'] * ncols

# The labels
labels = [None] * nrows * ncols

# The fontsize
fontsize = 40

# The titles
titles = drugs + [None] * (nrows - 1) * ncols

# The xlabels
xlabels = [None] * nrows * ncols

# The ylabels
ylabels = [None] * nrows * ncols

# The xticks
xticks = [None] * nrows * ncols

# The xticklabels
xticklabels = [[]] * ncols + [None] * ncols

# The decimal places
decimal_places = [1] * nrows * ncols

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, sharey=True, figsize=(30, 5.5), squeeze=False)

for row in range(nrows):
    for col in range(ncols):
        idx = row * ncols + col
        plot_distribution(row,
                          col,
                          file_names[idx], 
                          class_names[idx], 
                          feature_names[idx], 
                          colors[idx],
                          labels[idx],
                          fontsize,
                          titles[idx],
                          xlabels[idx],
                          ylabels[idx],
                          xticks[idx],
                          xticklabels[idx],
                          decimal_places[idx])
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/drug_consumption_fid_impulsive.pdf', dpi=300)
plt.show()

# %%
# The file names
drugs = 'Amphet, Benzos, Cannabis, Coke, Heroin, Ketamine, Legalh, LSD, Meth, Mushrooms'.split(',')
file_names = ['/Users/yhuang/Desktop/fid/result/ours/drug_consumption/'+ drug.strip() + '/prob_dists_file/drug_consumption.csv'for drug in drugs] * 2

# The row number
nrows = 2

# The column number
ncols = 10

# The class names
class_names = ['CL0'] * ncols + ['CL7'] * ncols

# The feature names
feature_names = ['SS'] * 2 * ncols

# The colors
colors = ['green'] * ncols + ['red'] * ncols

# The labels
labels = [None] * nrows * ncols

# The fontsize
fontsize = 40

# The titles
titles = drugs + [None] * (nrows - 1) * ncols

# The xlabels
xlabels = [None] * nrows * ncols

# The ylabels
ylabels = [None] * nrows * ncols

# The xticks
xticks = [None] * nrows * ncols

# The xticklabels
xticklabels = [[]] * ncols + [None] * ncols

# The decimal places
decimal_places = [1] * nrows * ncols

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, sharey=True, figsize=(30, 5.5), squeeze=False)

for row in range(nrows):
    for col in range(ncols):
        idx = row * ncols + col
        plot_distribution(row,
                          col,
                          file_names[idx], 
                          class_names[idx], 
                          feature_names[idx], 
                          colors[idx],
                          labels[idx],
                          fontsize,
                          titles[idx],
                          xlabels[idx],
                          ylabels[idx],
                          xticks[idx],
                          xticklabels[idx],
                          decimal_places[idx])
    
fig.tight_layout()
plt.savefig('/Users/yhuang/Desktop/fid/result/figure/drug_consumption_fid_ss.pdf', dpi=300)
plt.show()
